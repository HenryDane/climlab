# %%
import climlab
import numpy as np
import matplotlib.pyplot as plt

# %%
climlab.volume_state()
# Out:
# AttrDict({'Ts': Field([[[288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.]],
#
#        [[288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
#         [288.],
# ...
